# %%
import pandas as pd

# %% [markdown]
# - Creating dataset
#      - dictionary of items
#      - list of items
#      - importing csv files
#      - importing excel files
#      - json files
# - reading data
# - selection of data
# - cleaning of data
# - visualizing of data
# - saving the data

# %%
books ={
    "title": ["Great Expectations","To Kill a Mockingbird","Pride and Prejudice"],
    "author": ["Charles Dickinson","Harper Lee","Jane Austen"],
    "pages": [345,281,432],
    "price": [399,1099,199]
}
pd.DataFrame(books)
# Out:
#                    title             author  pages  price
# 0     Great Expectations  Charles Dickinson    345    399
# 1  To Kill a Mockingbird         Harper Lee    281   1099
# 2    Pride and Prejudice        Jane Austen    432    199

# %%
movies =[
    {"title": "To Kill a Mockingbird","director":"Robert Mullingan","length":129},
    {"title": "PK","director":"Rajkumar Hirani","length":153},
    {"title": "Forest Gump","director":"Robert Zemeckis","length":142}


]
pd.DataFrame(movies)
# Out:
#                    title          director  length
# 0  To Kill a Mockingbird  Robert Mullingan     129
# 1                     PK   Rajkumar Hirani     153
# 2            Forest Gump   Robert Zemeckis     142

# %%
df= pd.read_csv("kc_house_data.csv")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.sample()
df.sample(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 19047  4027700466  20141219T000000  340500.0         3        1.0
# 1771   2113700060  20141014T000000  400000.0         4        2.5
# 9486   7436600090  20150102T000000  287000.0         4        1.5
# 255    5101404898  20140519T000000  592500.0         2        2.0
# 13505  7010700580  20150303T000000  585000.0         2        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 19047         1770     12458     1.0           0     0  ...      7
# 1771          2350      3904     2.5           0     0  ...      7
# 9486          1300     10050     1.5           0     0  ...      7
# 255           1420      9191     1.5           0     2  ...      7
# 13505         1370      7920     1.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 19047        1770              0      1957             0    98155  47.7715
# ...

# %%
df.describe(include="object")
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#loc: index based selection

# %%
df.iloc[100]
# Out:
# id                    1952200240
# date             20140611T000000
# price                   850830.0
# bedrooms                       3
# bathrooms                    2.5
# sqft_living                 2070
# sqft_lot                   13241
# floors                       1.5
# waterfront                     0
# view                           0
# condition                      5
# grade                          9
# sqft_above                  1270
# sqft_basement                800
# yr_built                    1910
# yr_renovated                   0
# zipcode                    98102
# lat                      47.6415
# long                    -122.315
# sqft_living15               2200
# sqft_lot15                  4500
# Name: 100, dtype: object

# %%
df.iloc[[1,59,45,76]]
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 1   6414100192  20141209T000000  538000.0         3       2.25         2570
# 59  8079040320  20150223T000000  430000.0         4       3.00         1850
# 45  8035350320  20140718T000000  488000.0         3       2.50         3160
# 76  4036801170  20141013T000000  380000.0         4       1.75         1760
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 1       7242     2.0           0     0  ...      7        2170            400
# 59      9976     2.0           0     0  ...      8        1850              0
# 45     13603     2.0           0     0  ...      8        3160              0
# 76      7300     1.0           0     0  ...      7         880            880
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 1       1951          1991    98125  47.7210 -122.319           1690
# ...

# %%
df.iloc[[1,10,20],[2,3,4]]
# Out:
#        price  bedrooms  bathrooms
# 1   538000.0         3       2.25
# 10  662500.0         3       2.50
# 20  385000.0         4       1.75

# %%
df.iloc[50:61]
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 50  5245600105  20140916T000000  228000.0         3       1.00         1190
# 51  7231300125  20150217T000000  345000.0         5       2.50         3150
# 52  7518505990  20141231T000000  600000.0         3       1.75         1410
# 53  3626039271  20150205T000000  585000.0         2       1.75         1980
# 54  4217401195  20150303T000000  920000.0         5       2.25         2730
# 55  9822700295  20140512T000000  885000.0         4       2.50         2830
# 56  9478500640  20140819T000000  292500.0         4       2.50         2250
# 57  2799800710  20150407T000000  301000.0         3       2.50         2420
# 58  7922800400  20140827T000000  951000.0         5       3.25         3250
# 59  8079040320  20150223T000000  430000.0         4       3.00         1850
# 60  1516000055  20141210T000000  650000.0         3       2.25         2150
#
# ...

# %%
df["date"]
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21613, dtype: object

# %%
#loc: labelled based selection

# %%
df=df.set_index("id")
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.loc[2487200875]
# Out:
# date             20141209T000000
# price                   604000.0
# bedrooms                       4
# bathrooms                    3.0
# sqft_living                 1960
# sqft_lot                    5000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      5
# grade                          7
# sqft_above                  1050
# sqft_basement                910
# yr_built                    1965
# yr_renovated                   0
# zipcode                    98136
# lat                      47.5208
# long                    -122.393
# sqft_living15               1360
# sqft_lot15                  5000
# Name: 2487200875, dtype: object

# %% [markdown]
# ##### Column selection

# %%
df["price"]
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.price
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df[["price","bedrooms"]]
# Out:
#                price  bedrooms
# id
# 7129300520  221900.0         3
# 6414100192  538000.0         3
# 5631500400  180000.0         2
# 2487200875  604000.0         4
# 1954400510  510000.0         3
# ...              ...       ...
# 263000018   360000.0         3
# 6600060120  400000.0         4
# 1523300141  402101.0         2
# 291310100   400000.0         3
# 1523300157  325000.0         2
#
# [21613 rows x 2 columns]

# %% [markdown]
# ### Manipulating and Cleaning data
# - removing columns and rows
# - renaming columns
# - adding column
# - charging data types
# - handling missing values
# - dropping missing values
# - using apply() method

# %%
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.head(15)
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900.0         3       1.00         1180
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# 1321400060  20140627T000000   257500.0         3       2.25         1715
# 2008000270  20150115T000000   291850.0         3       1.50         1060
# 2414600126  20150415T000000   229500.0         3       1.00         1780
# 3793500160  20150312T000000   323000.0         3       2.50         1890
# 1736800520  20150403T000000   662500.0         3       2.50         3560
# 9212900260  20140527T000000   468000.0         2       1.00         1160
# ...

# %%
# to see the null values(NAN value)
df.info
# Out:
# <bound method DataFrame.info of                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
# ...

# %%
cols_to_drop=["sqft_living15","sqft_lot15"]
df=df.drop(columns=cols_to_drop)
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.drop(labels=[7129300520,6414100192])
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# 1321400060  20140627T000000   257500.0         3       2.25         1715
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
#shortcut way (this automatically removes all the rows with any NAN values)
df.dropna()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
#rename column name
name_update={
    "lat":"latitude",
    "long":"longitude"
}
df.rename(columns=name_update)
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.yr_built.dtype
# Out:
# dtype('int64')

# %%
#used for changing data type(astype)
df.yr_built.astype("float")
# Out:
# id
# 7129300520    1955.0
# 6414100192    1951.0
# 5631500400    1933.0
# 2487200875    1965.0
# 1954400510    1987.0
#                ...
# 263000018     2009.0
# 6600060120    2014.0
# 1523300141    2009.0
# 291310100     2004.0
# 1523300157    2008.0
# Name: yr_built, Length: 21613, dtype: float64

# %%
df.yr_built.astype("str")
# Out:
# id
# 7129300520    1955
# 6414100192    1951
# 5631500400    1933
# 2487200875    1965
# 1954400510    1987
#               ...
# 263000018     2009
# 6600060120    2014
# 1523300141    2009
# 291310100     2004
# 1523300157    2008
# Name: yr_built, Length: 21613, dtype: object

# %% [markdown]
# #### Another example of dataset with null values

# %%
import seaborn as sns

# %%
df= sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
avg_age=round(df["age"].mean())
print(avg_age)
# Out:
# 30

# %%
#
df["age"].fillna(avg_age,inplace=True)
# Out:
# C:\Users\Shivansh Kumar\AppData\Local\Temp\ipykernel_17848\2924003140.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(avg_age,inplace=True)

# %%
df["embark_town"].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["embark_town"].value_counts().idxmax()
# Out:
# 'Southampton'

# %%
df["embark_town"].value_counts().idxmin()
# Out:
# 'Queenstown'
